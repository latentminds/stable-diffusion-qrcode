# %% [markdown]
# <a href="https://colab.research.google.com/github/koll-ai/stable-diffusion-qrcode/blob/master/colabs/demo_sdqrcode_diffusers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sdqrcode
# !pip install git+https://github.com/holwech/diffusers

# %%
import sdqrcode

# %%
generator = sdqrcode.init(config = "default_diffusers")

# %%
images = generator.generate_sd_qrcode(height=768, width=768)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
images[0]
# Out:
# <PIL.Image.Image image mode=RGB size=768x768 at 0x7F4CCA2C6E30>
